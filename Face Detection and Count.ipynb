# %%
import cv2
from mtcnn.mtcnn import MTCNN
import matplotlib.pyplot as plt

# %%
detector = MTCNN()

input_image="face2.jpg"

image = cv2.imread(input_image)
result = detector.detect_faces(image)

#print("result==>",result)

# %% [markdown]
# ### As a result we will recive the following list from MTCNN()
#
#         [{'box': [305, 13, 33, 44],
#         'confidence': 0.9999947547912598,
#         'keypoints': {'left_eye': (316, 30),
#         'right_eye': (332, 32),
#         'nose': (325, 40),
#         'mouth_left': (314, 45),
#         'mouth_right': (331, 46)}}]
#
#
# > Box: will gives the values of pixels.
#
# > Confidance is about the score of face detection.
#
# > Keypoints are the other information about the face parameters.

# %%
for person in result:
            bounding_box = person['box']
            keypoints = person['keypoints']
    
            cv2.rectangle(image,
                          (bounding_box[0], bounding_box[1]),
                          (bounding_box[0]+bounding_box[2], bounding_box[1] + bounding_box[3]),
                          (0,155,255),
                          2)

# %%
print("we found {} number of faces".format(len(result)))
# Out:
# we found 23 number of faces

# %%
plt.axis("off")
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

plt.show()
